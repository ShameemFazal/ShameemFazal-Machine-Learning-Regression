# %%
import pandas as pd

# %%
dataset = pd.read_csv("insurance_pre.csv")

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset = pd.get_dummies(dataset,dtype=int,drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
independent=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]

# %%
dependent=dataset[['charges']]

# %%
independent
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0         0           1
# 1      18  33.770         1         1           0
# 2      28  33.000         3         1           0
# 3      33  22.705         0         1           0
# 4      32  28.880         0         1           0
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3         1           0
# 1334   18  31.920         0         0           0
# 1335   18  36.850         0         0           0
# 1336   21  25.800         0         0           0
# 1337   61  29.070         0         0           1
#
# [1338 rows x 5 columns]

# %%
dependent
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR

param_grid = {'kernel':['sigmoid','linear'],
'C':[10,100,1000,2000,3000],'gamma':['auto','scale']}

grid = GridSearchCV(SVR(), param_grid, refit = True, verbose = 3,n_jobs=-1)

# fitting the model for grid search
grid.fit(independent, dependent)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# C:\Anaconda\Lib\site-packages\sklearn\utils\validation.py:1339: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GridSearchCV(estimator=SVR(), n_jobs=-1,
#              param_grid={'C': [10, 100, 1000, 2000, 3000],
#                          'gamma': ['auto', 'scale'],
#                          'kernel': ['sigmoid', 'linear']},
#              verbose=3)

# %%
re=grid.cv_results_

grid_predictions = grid.predict(independent)

from sklearn.metrics import r2_score

r_score=r2_score(dependent,grid_predictions)

print("The R_score value for best parameter {}:".format(grid.best_params_),r_score)
# Out:
# The R_score value for best parameter {'C': 1000, 'gamma': 'auto', 'kernel': 'linear'}: 0.7179049746029832

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_C  \
# 0        1.126202      0.517417         0.019149    7.463658e-04       10
# 1        0.111404      0.005223         0.016756    3.989940e-04       10
# 2        0.123869      0.001163         0.025732    7.469781e-04       10
# 3        0.112100      0.004704         0.015559    4.884415e-04       10
# 4        0.093749      0.007543         0.018950    3.234067e-07      100
# 5        0.226993      0.010678         0.015957    6.298475e-04      100
# 6        0.121276      0.001621         0.025732    3.987552e-04      100
# 7        0.229985      0.013537         0.015957    6.303741e-04      100
# 8        0.089561      0.000977         0.018750    7.464550e-04     1000
# 9        0.868078      0.094806         0.015758    3.987079e-04     1000
# 10       0.124467      0.003699         0.025931    6.309773e-04     1000
# 11       0.853517      0.090757         0.015160    3.986838e-04     1000
# 12       0.089161      0.003546         0.017952    6.302988e-04     2000
# 13       1.419005      0.103593         0.015359    4.887919e-04     2000
# 14       0.121475      0.001323         0.025133    3.990174e-04     2000
# 15       1.401651      0.086506         0.015364    4.846668e-04     2000
# 16       0.092324      0.007145         0.017937    2.944947e-05     3000
# 17       2.590477      0.526876         0.015554    7.954451e-04     3000
# 18       0.121873      0.002476         0.025333    4.883636e-04     3000
# 19       3.167933      1.187026         0.023537    8.310383e-03     3000
#
#    param_gamma param_kernel  \
# 0         auto      sigmoid
# 1         auto       linear
# 2        scale      sigmoid
# 3        scale       linear
# 4         auto      sigmoid
# 5         auto       linear
# 6        scale      sigmoid
# 7        scale       linear
# 8         auto      sigmoid
# 9         auto       linear
# 10       scale      sigmoid
# 11       scale       linear
# 12        auto      sigmoid
# 13        auto       linear
# 14       scale      sigmoid
# 15       scale       linear
# 16        auto      sigmoid
# 17        auto       linear
# 18       scale      sigmoid
# 19       scale       linear
#
#                                                params  split0_test_score  \
# 0     {'C': 10, 'gamma': 'auto', 'kernel': 'sigmoid'}          -0.115328
# 1      {'C': 10, 'gamma': 'auto', 'kernel': 'linear'}          -0.018943
# 2    {'C': 10, 'gamma': 'scale', 'kernel': 'sigmoid'}          -0.116743
# 3     {'C': 10, 'gamma': 'scale', 'kernel': 'linear'}          -0.018943
# 4    {'C': 100, 'gamma': 'auto', 'kernel': 'sigmoid'}          -0.115328
# 5     {'C': 100, 'gamma': 'auto', 'kernel': 'linear'}           0.559313
# 6   {'C': 100, 'gamma': 'scale', 'kernel': 'sigmoid'}          -0.142455
# 7    {'C': 100, 'gamma': 'scale', 'kernel': 'linear'}           0.559313
# 8   {'C': 1000, 'gamma': 'auto', 'kernel': 'sigmoid'}          -0.115328
# 9    {'C': 1000, 'gamma': 'auto', 'kernel': 'linear'}           0.736398
# 10  {'C': 1000, 'gamma': 'scale', 'kernel': 'sigmo...          -2.043140
# 11  {'C': 1000, 'gamma': 'scale', 'kernel': 'linear'}           0.736398
# 12  {'C': 2000, 'gamma': 'auto', 'kernel': 'sigmoid'}          -0.115328
# 13   {'C': 2000, 'gamma': 'auto', 'kernel': 'linear'}           0.682349
# 14  {'C': 2000, 'gamma': 'scale', 'kernel': 'sigmo...          -7.209317
# 15  {'C': 2000, 'gamma': 'scale', 'kernel': 'linear'}           0.682349
# 16  {'C': 3000, 'gamma': 'auto', 'kernel': 'sigmoid'}          -0.115328
# 17   {'C': 3000, 'gamma': 'auto', 'kernel': 'linear'}           0.677778
# 18  {'C': 3000, 'gamma': 'scale', 'kernel': 'sigmo...         -15.561853
# 19  {'C': 3000, 'gamma': 'scale', 'kernel': 'linear'}           0.677778
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0           -0.113567          -0.081608          -0.106067
# 1            0.029886           0.022167           0.003112
# 2           -0.119312          -0.085214          -0.108210
# 3            0.029886           0.022167           0.003112
# 4           -0.113567          -0.081608          -0.106067
# 5            0.521798           0.547691           0.538805
# 6           -0.160831          -0.117544          -0.137984
# 7            0.521798           0.547691           0.538805
# 8           -0.113567          -0.081608          -0.106067
# 9            0.675162           0.680002           0.699377
# 10          -2.686121          -2.194563          -2.210858
# 11           0.675162           0.680002           0.699377
# 12          -0.113567          -0.081608          -0.106067
# 13           0.630642           0.750714           0.646368
# 14          -9.282940          -7.776578          -7.745074
# 15           0.630642           0.750714           0.646368
# 16          -0.113567          -0.081608          -0.106067
# 17           0.626814           0.732806           0.633479
# 18         -20.498908         -17.095474         -16.750877
# 19           0.626814           0.732806           0.633479
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0           -0.107195        -0.104753        0.012107               11
# 1           -0.066653        -0.006086        0.034672                9
# 2           -0.108716        -0.107639        0.012029               16
# 3           -0.066653        -0.006086        0.034672                9
# 4           -0.107195        -0.104753        0.012107               11
# 5            0.508518         0.535225        0.018122                7
# 6           -0.130402        -0.137843        0.014263               17
# 7            0.508518         0.535225        0.018122                7
# 8           -0.107195        -0.104753        0.012107               11
# 9            0.677952         0.693778        0.022955                1
# 10          -1.942521        -2.215441        0.255409               18
# 11           0.677952         0.693778        0.022955                1
# 12          -0.107195        -0.104753        0.012107               11
# 13           0.722261         0.686467        0.045056                3
# 14          -6.891719        -7.781126        0.821557               19
# 15           0.722261         0.686467        0.045056                3
# 16          -0.107195        -0.104753        0.012107               11
# 17           0.698692         0.673914        0.039876                5
# 18         -15.012168       -16.983856        1.914783               20
# 19           0.698692         0.673914        0.039876                5

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age: 41
# BMI: 36
# Children: 3
# Sex Male 0 or 1: 1
# Smoker Yes 0 or 1: 0

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[8276.99263519]
# C:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
