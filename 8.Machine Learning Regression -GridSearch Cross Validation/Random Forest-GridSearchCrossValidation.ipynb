# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv('insurance_pre.csv')

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset = pd.get_dummies(dataset,dtype=int,drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
independent=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]

# %%
dependent=dataset[['charges']]

# %%
independent
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0         0           1
# 1      18  33.770         1         1           0
# 2      28  33.000         3         1           0
# 3      33  22.705         0         1           0
# 4      32  28.880         0         1           0
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3         1           0
# 1334   18  31.920         0         0           0
# 1335   18  36.850         0         0           0
# 1336   21  25.800         0         0           0
# 1337   61  29.070         0         0           1
#
# [1338 rows x 5 columns]

# %%
dependent
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
 from sklearn.model_selection import GridSearchCV
param_grid = {'criterion':['squared_error','poisson','friedman_mse','absolute_error'],'max_features': ['sqrt','log2'],'n_estimators':[10,100]}
grid = GridSearchCV(RandomForestRegressor(), param_grid, refit = True, verbose=3,n_jobs=-1)

# %%
grid.fit(independent,dependent)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# C:\Anaconda\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'poisson',
#                                        'friedman_mse', 'absolute_error'],
#                          'max_features': ['sqrt', 'log2'],
#                          'n_estimators': [10, 100]},
#              verbose=3)

# %%
re=grid.cv_results_

grid_predictions = grid.predict(independent)

from sklearn.metrics import r2_score

r_score=r2_score(dependent,grid_predictions)

print("The R_score value for best parameter {}:".format(grid.best_params_),r_score)
# Out:
# The R_score value for best parameter {'criterion': 'squared_error', 'max_features': 'sqrt', 'n_estimators': 100}: 0.9754564255624077

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.049666      0.008794         0.006384        0.001017
# 1        0.370807      0.003534         0.015958        0.000631
# 2        0.041687      0.000977         0.004788        0.000399
# 3        0.374797      0.004902         0.015758        0.000399
# 4        0.065424      0.001493         0.005186        0.000399
# 5        0.607176      0.006096         0.016157        0.000746
# 6        0.065424      0.001017         0.004787        0.000399
# 7        0.608772      0.005485         0.017553        0.001353
# 8        0.042087      0.001466         0.004788        0.000399
# 9        0.370808      0.001934         0.016357        0.000488
# 10       0.040691      0.000399         0.004788        0.000399
# 11       0.373600      0.005448         0.015758        0.000399
# 12       0.130451      0.003858         0.004787        0.000399
# 13       1.267808      0.013637         0.015160        0.000399
# 14       0.136832      0.004058         0.004389        0.000489
# 15       1.110437      0.179782         0.013364        0.001955
#
#    param_criterion param_max_features  param_n_estimators  \
# 0    squared_error               sqrt                  10
# 1    squared_error               sqrt                 100
# 2    squared_error               log2                  10
# 3    squared_error               log2                 100
# 4          poisson               sqrt                  10
# 5          poisson               sqrt                 100
# 6          poisson               log2                  10
# 7          poisson               log2                 100
# 8     friedman_mse               sqrt                  10
# 9     friedman_mse               sqrt                 100
# 10    friedman_mse               log2                  10
# 11    friedman_mse               log2                 100
# 12  absolute_error               sqrt                  10
# 13  absolute_error               sqrt                 100
# 14  absolute_error               log2                  10
# 15  absolute_error               log2                 100
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.841201
# 1   {'criterion': 'squared_error', 'max_features':...           0.859317
# 2   {'criterion': 'squared_error', 'max_features':...           0.843935
# 3   {'criterion': 'squared_error', 'max_features':...           0.856405
# 4   {'criterion': 'poisson', 'max_features': 'sqrt...           0.849284
# 5   {'criterion': 'poisson', 'max_features': 'sqrt...           0.858011
# 6   {'criterion': 'poisson', 'max_features': 'log2...           0.847880
# 7   {'criterion': 'poisson', 'max_features': 'log2...           0.857352
# 8   {'criterion': 'friedman_mse', 'max_features': ...           0.842309
# 9   {'criterion': 'friedman_mse', 'max_features': ...           0.858742
# 10  {'criterion': 'friedman_mse', 'max_features': ...           0.851747
# 11  {'criterion': 'friedman_mse', 'max_features': ...           0.860392
# 12  {'criterion': 'absolute_error', 'max_features'...           0.846202
# 13  {'criterion': 'absolute_error', 'max_features'...           0.854251
# 14  {'criterion': 'absolute_error', 'max_features'...           0.846537
# 15  {'criterion': 'absolute_error', 'max_features'...           0.858826
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.758754           0.842556           0.819042
# 1            0.782271           0.860139           0.829276
# 2            0.760748           0.834945           0.811778
# 3            0.784805           0.860373           0.824404
# 4            0.748560           0.814713           0.811820
# 5            0.776823           0.858362           0.827294
# 6            0.767599           0.854429           0.816279
# 7            0.783602           0.859052           0.827986
# 8            0.774776           0.852426           0.819032
# 9            0.776569           0.864995           0.827773
# 10           0.764793           0.837684           0.816643
# 11           0.779566           0.860307           0.829494
# 12           0.765219           0.838805           0.824258
# 13           0.777241           0.854684           0.826526
# 14           0.773869           0.821247           0.829975
# 15           0.776996           0.854358           0.827636
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.823949         0.817100        0.030607               15
# 1            0.839034         0.834007        0.028453                1
# 2            0.839286         0.818138        0.030755               13
# 3            0.841257         0.833449        0.027426                4
# 4            0.821722         0.809220        0.033100               16
# 5            0.840123         0.832123        0.030013                7
# 6            0.828890         0.823015        0.030841               10
# 7            0.838772         0.833353        0.027458                5
# 8            0.835046         0.824718        0.027241                9
# 9            0.840302         0.833676        0.031461                3
# 10           0.816076         0.817389        0.029533               14
# 11           0.840143         0.833981        0.029698                2
# 12           0.819047         0.818706        0.028467               12
# 13           0.839863         0.830513        0.028597                8
# 14           0.840744         0.822474        0.025819               11
# 15           0.844836         0.832530        0.029757                6

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age: 41
# BMI: 36
# Children: 3
# Sex Male 0 or 1: 1
# Smoker Yes 0 or 1: 0

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[7388.873923]
# C:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
